# %%
import pandas as pd
import altair as alt
import numpy as np
dat = pd.read_csv('https://github.com/byuidatascience/data4missing/raw/master/data-raw/mtcars_missing/mtcars_missing.csv')

# %%
dat.head()
# Out:
#                  car   mpg  cyl   disp     hp  drat     wt   qsec   vs  am  \
# 0          Mazda RX4  21.0    6  160.0  110.0  3.90  2.620  16.46  0.0   1
# 1      Mazda RX4 Wag  21.0    6  160.0  110.0  3.90  2.875  17.02  NaN   1
# 2         Datsun 710  22.8    4  108.0   93.0  3.85  2.320  18.61  1.0   1
# 3     Hornet 4 Drive  21.4    6  258.0  110.0  3.08    NaN  19.44  1.0   0
# 4  Hornet Sportabout  18.7    8  360.0  175.0  3.15  3.440  17.02  0.0   0
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2   999     1
# 3     3     1
# 4     3     2

# %%
graphic = (alt.Chart(dat,title="This is Awesome").encode(
    x= 'hp',
    y ='mpg'
).mark_circle(color ='red')
)

#graphic1 =alt.Chart(pd.dat({'hp': [80]})).mark_rule().encode(y='mpg')
#graphic2 =alt.Chart(pd.dat({'hp': [160]})).mark_rule().encode(y='mpg')
#graphic3 = graphic + graphic1 + graphic2
graphic
# Out:
# alt.Chart(...)
